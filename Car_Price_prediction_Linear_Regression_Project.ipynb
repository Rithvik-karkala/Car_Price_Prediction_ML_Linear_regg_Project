# %%
import pandas as pd
import numpy as np
import seaborn as sns 
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Downloads/car details v4.csv')

# %%
df.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
df.shape
# Out:
# (2059, 20)

# %%
#Checking all columns of data 
df.columns
# Out:
# Index(['Make', 'Model', 'Price', 'Year', 'Kilometer', 'Fuel Type',
#        'Transmission', 'Location', 'Color', 'Owner', 'Seller Type', 'Engine',
#        'Max Power', 'Max Torque', 'Drivetrain', 'Length', 'Width', 'Height',
#        'Seating Capacity', 'Fuel Tank Capacity'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  2.059000e+03  2059.000000  2.059000e+03  1995.000000  1995.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419881e+06     3.363564  5.736172e+04   442.458507   135.265825
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.500000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1995.000000       1995.000000         1946.000000
# mean   1591.735338          5.306266           52.002210
# std     136.073956          0.822170           15.110198
# min    1165.000000          2.000000           15.000000
# ...

# %%
df.dtypes
# Out:
# Make                   object
# Model                  object
# Price                   int64
# Year                    int64
# Kilometer               int64
# Fuel Type              object
# Transmission           object
# Location               object
# Color                  object
# Owner                  object
# Seller Type            object
# Engine                 object
# Max Power              object
# Max Torque             object
# Drivetrain             object
# Length                float64
# Width                 float64
# Height                float64
# Seating Capacity      float64
# Fuel Tank Capacity    float64
# dtype: object

# %%
df.describe(include='object')
# Out:
#                  Make               Model Fuel Type Transmission Location  \
# count            2059                2059      2059         2059     2059
# unique             33                1050         9            2       77
# top     Maruti Suzuki  X1 sDrive20d xLine    Diesel       Manual   Mumbai
# freq              440                  15      1049         1133      342
#
#         Color  Owner Seller Type   Engine          Max Power  \
# count    2059   2059        2059     1979               1979
# unique     17      6           3      108                335
# top     White  First  Individual  1197 cc  89 bhp @ 4000 rpm
# freq      802   1619        1997      231                 90
#
#                Max Torque Drivetrain
# count                1979       1923
# unique                290          3
# top     200 Nm @ 1750 rpm        FWD
# freq                   90       1330

# %%
#EDA process of changing categorical data into numerical data

df.loc[df['Owner']=='First','Owner_num']=1
df.loc[df['Owner']=='Second','Owner_num']=2
df.loc[df['Owner']=='Third','Owner_num']=3
df.loc[df['Owner']=='Fourth','Owner_num']=4
df.loc[df['Owner']=='Fifth','Owner_num']=5
df.loc[df['Owner']=='Sixth','Owner_num']=6

# %%
df.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner  ...   Engine  \
# 0    Petrol       Manual       Pune    Grey   First  ...  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  ...  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  ...  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  ...  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  ...  2393 cc
#
#             Max Power              Max Torque Drivetrain  Length   Width  \
# ...

# %%
#checking NA values 
df.Owner_num.unique()
# Out:
# array([ 1.,  2.,  3.,  4., nan])

# %%
df.Owner_num
# Out:
# 0       1.0
# 1       2.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 2054    1.0
# 2055    2.0
# 2056    1.0
# 2057    1.0
# 2058    1.0
# Name: Owner_num, Length: 2059, dtype: float64

# %%
#removing null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Price                   0
# Year                    0
# Kilometer               0
# Fuel Type               0
# Transmission            0
# Location                0
# Color                   0
# Owner                   0
# Seller Type             0
# Engine                 80
# Max Power              80
# Max Torque             80
# Drivetrain            136
# Length                 64
# Width                  64
# Height                 64
# Seating Capacity       64
# Fuel Tank Capacity    113
# Owner_num              22
# dtype: int64

# %%
sns.pairplot(df)

# %%
df[df['Engine'].isna()]
# Out:
#                Make                        Model    Price  Year  Kilometer  \
# 33            Honda                  CR-V 2.4 AT   860000  2013      67000
# 69             Audi         A4 2.0 TDI (143 bhp)  1250000  2012      50000
# 94    Mercedes-Benz              GLC 220 d Sport  3900000  2018      83400
# 108           Honda                    Brio S MT   229000  2013      38175
# 127            Tata             Nexon EV XZ Plus  1375000  2021      16000
# ...             ...                          ...      ...   ...        ...
# 1906             MG  ZS EV Exclusive [2020-2021]  2100000  2020      38500
# 1928        Porsche        Cayenne 3.2 V6 Petrol  3600000  2014      43000
# 1980  Maruti Suzuki  Wagon R VXi 1.0 [2019-2019]   420000  2018      50000
# 2009           Audi             A4 2.0 TDI Sline   775000  2012      89000
# 2025          Honda          Accord 2.4 iVtec AT   195000  2008      57885
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.head(15)
# Out:
#              Make                                 Model    Price  Year  \
# 0           Honda                   Amaze 1.2 VX i-VTEC   505000  2017
# 1   Maruti Suzuki                       Swift DZire VDI   450000  2014
# 2         Hyundai                  i10 Magna 1.2 Kappa2   220000  2011
# 3          Toyota                              Glanza G   799000  2019
# 4          Toyota       Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# 5   Maruti Suzuki                              Ciaz ZXi   675000  2017
# 7             BMW                  X1 xDrive20d M Sport  2650000  2017
# 8           Skoda  Octavia 1.8 TSI Style Plus AT [2017]  1390000  2017
# 9          Nissan                        Terrano XL (D)   575000  2015
# 10        Hyundai                  Elite i20 Sportz 1.2   591000  2017
# 11        Renault              Kwid 1.0 RXT [2016-2019]   459999  2018
# 12  Maruti Suzuki  Ciaz Alpha Hybrid 1.5 AT [2018-2020]  1075000  2019
# ...

# %%
df[df['Engine'].isna()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Price, Year, Kilometer, Fuel Type, Transmission, Location, Color, Owner, Seller Type, Engine, Max Power, Max Torque, Drivetrain, Length, Width, Height, Seating Capacity, Fuel Tank Capacity, Owner_num]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Price                 0
# Year                  0
# Kilometer             0
# Fuel Type             0
# Transmission          0
# Location              0
# Color                 0
# Owner                 0
# Seller Type           0
# Engine                0
# Max Power             0
# Max Torque            0
# Drivetrain            0
# Length                0
# Width                 0
# Height                0
# Seating Capacity      0
# Fuel Tank Capacity    0
# Owner_num             0
# dtype: int64

# %%
#no null values in the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1856 entries, 0 to 2057
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                1856 non-null   object
#  1   Model               1856 non-null   object
#  2   Price               1856 non-null   int64
#  3   Year                1856 non-null   int64
#  4   Kilometer           1856 non-null   int64
#  5   Fuel Type           1856 non-null   object
#  6   Transmission        1856 non-null   object
#  7   Location            1856 non-null   object
#  8   Color               1856 non-null   object
#  9   Owner               1856 non-null   object
#  10  Seller Type         1856 non-null   object
#  11  Engine              1856 non-null   object
#  12  Max Power           1856 non-null   object
#  13  Max Torque          1856 non-null   object
#  14  Drivetrain          1856 non-null   object
# ...

# %%
#converting Owner_num column from float to int 
df['Owner_num']=df['Owner_num'].astype('int')

# %%
df.dtypes
# Out:
# Make                   object
# Model                  object
# Price                   int64
# Year                    int64
# Kilometer               int64
# Fuel Type              object
# Transmission           object
# Location               object
# Color                  object
# Owner                  object
# Seller Type            object
# Engine                 object
# Max Power              object
# Max Torque             object
# Drivetrain             object
# Length                float64
# Width                 float64
# Height                float64
# Seating Capacity      float64
# Fuel Tank Capacity    float64
# Owner_num               int64
# dtype: object

# %%
df.head()
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner  ...   Engine  \
# 0    Petrol       Manual       Pune    Grey   First  ...  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  ...  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  ...  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  ...  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  ...  2393 cc
#
#             Max Power              Max Torque Drivetrain  Length   Width  \
# ...

# %%
sns.pairplot(df)

# %%
#Corrilation graph for feature engineering 

corrmat=df.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
#as fuel capacity has good corrilation with price, 
#checking the price predition with just one variable

# %%
df_fc=df[['Fuel Tank Capacity','Price']].copy()

# %%
df_fc
# Out:
#       Fuel Tank Capacity    Price
# 0                   35.0   505000
# 1                   42.0   450000
# 2                   35.0   220000
# 3                   37.0   799000
# 4                   55.0  1950000
# ...                  ...      ...
# 2053                43.0   245000
# 2054                70.0   850000
# 2055                32.0   275000
# 2056                45.0   240000
# 2057                65.0  4290000
#
# [1856 rows x 2 columns]

# %%
plt.scatter(df_fc['Fuel Tank Capacity'],df_fc['Price'])

# %%
X=df_fc['Fuel Tank Capacity'].copy()
y=df_fc['Price'].copy()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train=pd.DataFrame(X_train)
X_test=pd.DataFrame(X_test)

# %%
X_train.shape
# Out:
# (1484, 1)

# %%
y_pred_test = lm.predict(X_test)     
y_pred_train = lm.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test.values,y_pred_test)
# Out:
# 0.2791196878701939

# %%
y_pred_test
# Out:
# array([4283912.99318858, 4099858.50746914, -593530.87837671,
#        1062959.4930983 , 2443368.13599413,  418768.79308024,
#        -170889.021409  , 2443368.13599413,  142687.06450107,
#        1062959.4930983 , 1523095.70739691, 1062959.4930983 ,
#        3363640.56459136,  878905.00737885, -170889.021409  ,
#         786877.76451913, 4283912.99318858, -170889.021409  ,
#         326741.55022052,  142687.06450107,  878905.00737885,
#         602823.27879968,  602823.27879968, 1062959.4930983 ,
#        1339041.22167746, 1983231.92169552, 2129792.05008406,
#        1301546.86434656, 1062959.4930983 ,  251752.8355587 ,
#        2903504.35029275,  786877.76451913, 2995531.59315247,
#         878905.00737885,  142687.06450107, 2443368.13599413,
#         970932.25023857, 1062959.4930983 ,  142687.06450107,
#        -133394.6640781 , 4283912.99318858, 2681955.50724239,
#         142687.06450107, 2681955.50724239, 2443368.13599413,
# ...

# %%
y_test
# Out:
# 608      2980000
# 483     35000000
# 1100      425000
# 1663     1175000
# 19        740000
#           ...
# 1941      625000
# 1423      434000
# 1857      365000
# 1204      650000
# 1157      835000
# Name: Price, Length: 372, dtype: int64

# %%
#As the model gave bad accuracy, trying to train the model with more independent variables

# %%
df_sc=df[['Fuel Tank Capacity','Owner_num','Price']].copy()
df_sc
# Out:
#       Fuel Tank Capacity  Owner_num    Price
# 0                   35.0          1   505000
# 1                   42.0          2   450000
# 2                   35.0          1   220000
# 3                   37.0          1   799000
# 4                   55.0          1  1950000
# ...                  ...        ...      ...
# 2053                43.0          2   245000
# 2054                70.0          1   850000
# 2055                32.0          2   275000
# 2056                45.0          1   240000
# 2057                65.0          1  4290000
#
# [1856 rows x 3 columns]

# %%
X=df[['Fuel Tank Capacity','Owner_num','Year',]].copy()
y=df['Price'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.shape
# Out:
# (1484, 3)

# %%
X_test.shape
# Out:
# (372, 3)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = lm.predict(X_test)     
y_pred_train = lm.predict(X_train)

# %%
r2_score(y_test.values,y_pred_test)
# Out:
# 0.32589899195106753

# %%
#we see a very sligth increase in accuracy adding Year and Number of Owners into the train, 
#test data

# %%
df_sc=df[['Fuel Tank Capacity','Owner_num','Price','Year','Kilometer','Length']].copy()
df_sc
# Out:
#       Fuel Tank Capacity  Owner_num    Price  Year  Kilometer  Length
# 0                   35.0          1   505000  2017      87150  3990.0
# 1                   42.0          2   450000  2014      75000  3995.0
# 2                   35.0          1   220000  2011      67000  3585.0
# 3                   37.0          1   799000  2019      37500  3995.0
# 4                   55.0          1  1950000  2018      69000  4735.0
# ...                  ...        ...      ...   ...        ...     ...
# 2053                43.0          2   245000  2014      79000  3775.0
# 2054                70.0          1   850000  2016      90300  4585.0
# 2055                32.0          2   275000  2014      83000  3495.0
# 2056                45.0          1   240000  2013      73000  3795.0
# 2057                65.0          1  4290000  2018      60474  4936.0
#
# [1856 rows x 6 columns]

# %%
X=df[['Fuel Tank Capacity','Owner_num','Year','Kilometer','Length']].copy()
y=df['Price'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = lm.predict(X_test)     
y_pred_train = lm.predict(X_train)

# %%
r2_score(y_test.values,y_pred_test)
# Out:
# 0.35389858595966484
